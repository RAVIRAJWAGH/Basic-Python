# %%
import numpy as np
import pandas as pd

# %%
# replace()
# np.array_split()
## simple split in ratio 80:20
# str.split().str.get()
# rename()

# %%
data=pd.read_csv(r"C:\Users\Parimal\Downloads\HousePrice.csv")
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %% [markdown]
# ### raplace()

# %%
data["POSTED_BY"].replace("Owner","Raviraj",inplace=True)

# %%
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0       Raviraj                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2       Raviraj                   0     0        2       BHK   933.159722
# 3       Raviraj                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446   Raviraj                   0     0        3       BHK  2500.000000
# 29447   Raviraj                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449   Raviraj                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %% [markdown]
# ### np.array_Split()

# %%
l=[2,5,8,7,6,7]

# %%
np.array_split(l,2)
# Out:
# [array([2, 5, 8]), array([7, 6, 7])]

# %%
np.array_split(l,4)
# Out:
# [array([2, 5]), array([8, 7]), array([6]), array([7])]

# %% [markdown]
# ### simple split in ratio 80:20

# %%
a=np.array_split(data,10)
a
# Out:
# [     POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
#  0      Raviraj                   0     0        2       BHK  1300.236407
#  1       Dealer                   0     0        2       BHK  1275.000000
#  2      Raviraj                   0     0        2       BHK   933.159722
#  3      Raviraj                   0     1        2       BHK   929.921143
#  4       Dealer                   1     0        2       BHK   999.009247
#  ...        ...                 ...   ...      ...       ...          ...
#  2941   Raviraj                   0     0        3       BHK  1404.001404
#  2942   Raviraj                   0     1        3       BHK  1555.176821
#  2943    Dealer                   0     1        3       BHK   862.068965
#  2944    Dealer                   0     0        1       BHK   494.030465
#  2945   Builder                   1     0        2       BHK  1216.842105
#
#        READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE  \
# ...

# %%
np.shape(a)
# Out:
# (10,)

# %%
train=np.concatenate(a[0:8])
train
# Out:
# array([['Raviraj', 0, 0, ..., 12.96991, 77.59796, 55.0],
#        ['Dealer', 0, 0, ..., 12.274538, 76.644605, 51.0],
#        ['Raviraj', 0, 0, ..., 12.778033, 77.632191, 43.0],
#        ...,
#        ['Dealer', 0, 0, ..., 19.1758, 72.8643, 170.0],
#        ['Dealer', 0, 1, ..., 21.56128, 74.21238000000001, 61.0],
#        ['Dealer', 0, 0, ..., 18.5442, 73.7948, 85.0]], dtype=object)

# %%
train_d=pd.DataFrame(train)
train_d
# Out:
#             0  1  2  3    4            5  6  7                            8   \
# 0      Raviraj  0  0  2  BHK  1300.236407  1  1        Ksfc Layout,Bangalore
# 1       Dealer  0  0  2  BHK       1275.0  1  1    Vishweshwara Nagar,Mysore
# 2      Raviraj  0  0  2  BHK   933.159722  1  1             Jigani,Bangalore
# 3      Raviraj  0  1  2  BHK   929.921143  1  1  Sector-1 Vaishali,Ghaziabad
# 4       Dealer  1  0  2  BHK   999.009247  0  1             New Town,Kolkata
# ...        ... .. .. ..  ...          ... .. ..                          ...
# 23556   Dealer  1  0  2  BHK  1174.934726  0  1        Sector-16 Ulwe,Mumbai
# 23557  Builder  1  1  2  BHK  1165.892099  0  0        Thanisandra,Bangalore
# 23558   Dealer  0  0  2  BHK  1262.907659  1  1        Malad (East),Lalitpur
# 23559   Dealer  0  1  2  BHK  1040.068201  1  1           Taloja,Maharashtra
# 23560   Dealer  0  0  2  BHK  1100.038825  1  1                  Pashan,Pune
#
#               9          10     11
# ...

# %% [raw]
# test_d=pd.Data_Frame(a[8:10])
# test_d

# %%
b=a[8:10]
b
# Out:
# [      POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
#  23561    Dealer                   0     1        2       BHK  1239.473684
#  23562   Raviraj                   0     0        2       BHK   968.686641
#  23563    Dealer                   1     0        2       BHK   980.100980
#  23564   Raviraj                   0     0        1       BHK   700.097688
#  23565   Builder                   1     1        1       BHK   565.130261
#  ...         ...                 ...   ...      ...       ...          ...
#  26501    Dealer                   0     1        2       BHK  1203.548711
#  26502    Dealer                   0     0        2       BHK  1023.100533
#  26503   Raviraj                   0     0        2       BHK  1119.917298
#  26504   Raviraj                   0     0        2       BHK  1245.124512
#  26505    Dealer                   0     1        2       BHK  1400.147384
#
# ...

# %%
b=np.concatenate(b)

# %%
test_d=pd.DataFrame(b)
test_d
# Out:
#            0  1  2  3    4            5  6  7   \
# 0      Dealer  0  1  2  BHK  1239.473684  1  1
# 1     Raviraj  0  0  2  BHK   968.686641  1  1
# 2      Dealer  1  0  2  BHK    980.10098  0  1
# 3     Raviraj  0  0  1  BHK   700.097688  1  1
# 4     Builder  1  1  1  BHK   565.130261  0  0
# ...       ... .. .. ..  ...          ... .. ..
# 5885  Raviraj  0  0  3  BHK       2500.0  1  1
# 5886  Raviraj  0  0  2  BHK   769.230769  1  1
# 5887   Dealer  0  0  2  BHK  1022.641509  1  1
# 5888  Raviraj  0  0  2  BHK   927.079009  1  1
# 5889   Dealer  0  1  2  BHK   896.774194  1  1
#
#                                      8          9          10    11
# 0                 Faizabad Road,Lucknow   26.86056   80.91583  47.1
# 1                        Carambolim,Goa  15.459622  73.941404  43.0
# 2                     Ambapua,Berhampur  19.304032  84.610965  33.0
# 3           Mansarovar Extension,Jaipur    26.8626    75.7633  21.5
# ...

# %% [markdown]
# ### str.split().str.get()

# %%
data["ADDRESS"]=data["ADDRESS"].str.split(",").str.get(1)

# %%
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0       Raviraj                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2       Raviraj                   0     0        2       BHK   933.159722
# 3       Raviraj                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446   Raviraj                   0     0        3       BHK  2500.000000
# 29447   Raviraj                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449   Raviraj                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE               ADDRESS  LONGITUDE   LATITUDE  \
# ...

# %%
data["POSTED_BY"].value_counts()
# Out:
# Dealer     18291
# Raviraj    10538
# Builder      622
# Name: POSTED_BY, dtype: int64

# %% [markdown]
# ### rename()

# %%
data.rename(columns={"POSTED_BY":"RAVI'S"})
# Out:
#         RAVI'S  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0      Raviraj                   0     0        2       BHK  1300.236407
# 1       Dealer                   0     0        2       BHK  1275.000000
# 2      Raviraj                   0     0        2       BHK   933.159722
# 3      Raviraj                   0     1        2       BHK   929.921143
# 4       Dealer                   1     0        2       BHK   999.009247
# ...        ...                 ...   ...      ...       ...          ...
# 29446  Raviraj                   0     0        3       BHK  2500.000000
# 29447  Raviraj                   0     0        2       BHK   769.230769
# 29448   Dealer                   0     0        2       BHK  1022.641509
# 29449  Raviraj                   0     0        2       BHK   927.079009
# 29450   Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE               ADDRESS  LONGITUDE   LATITUDE  \
# ...
